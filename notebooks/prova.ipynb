# %% [markdown]
# <a href="https://colab.research.google.com/github/andreasangi/Prog-Machine-Learning/blob/main/prova.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello rld")
print("hello")
